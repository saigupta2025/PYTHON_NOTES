# %% [markdown]
# <a href="https://colab.research.google.com/github/saigupta2025/PYTHON_NOTES/blob/main/ERRORS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(x)   # x is not defined
# Out:
# 10

# %%
print("5" + 16)   # cannot add string and integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3843425102.py in <cell line: 0>()
# ----> 1 print("5" + 16)   # cannot add string and integer
#
# TypeError: can only concatenate str (not "int") to str

# %%
num = int("abcde")  # cannot convert 'abc' to integer
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-723429329.py in <cell line: 0>()
# ----> 1 num = int("abcde")  # cannot convert 'abc' to integer
#
# ValueError: invalid literal for int() with base 10: 'abcde'

# %%
lst = [1, 2, 4]
print(lst[5])  # index 5 doesn’t exist
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3498104826.py in <cell line: 0>()
#       1 lst = [1, 2, 4]
# ----> 2 print(lst[5])  # index 5 doesn’t exist
#
# IndexError: list index out of range

# %%
d = {"name": "Sai"}
print(d["age"])  # 'age' key does not exist
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2563437231.py in <cell line: 0>()
#       1 d = {"name": "Sai"}
# ----> 2 print(d["age"])  # 'age' key does not exist
#
# KeyError: 'age'

# %%
x = 10
x.append(5)   # integers don’t have append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2357184637.py in <cell line: 0>()
#       1 x = 10
# ----> 2 x.append(5)   # integers don’t have append()
#
# AttributeError: 'int' object has no attribute 'append'

# %%
print(10 / 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-186921146.py in <cell line: 0>()
# ----> 1 print(10 / 0)
#
# ZeroDivisionError: division by zero

# %%
import math  # should be 'math'

# %%
def func():
print("Hello")   # no indentation
# Out:
#   File "/tmp/ipython-input-1177164652.py", line 1
#     def func()
#               ^
# SyntaxError: expected ':'

# %%
raise RuntimeError("Something went wrong")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3303990789.py in <cell line: 0>()
# ----> 1 raise RuntimeError("Something went wrong")
#
# RuntimeError: Something went wrong

# %%
# Out:
# 10
